# %%
import pandas as pd

# %%
df = pd.read_parquet("C:/Users/paulh/Desktop/projects/AAD/analytics-application-development-uni/Auftragsdaten.parquet")

# %%
df.dtypes
# Out:
# Auftrag_ID                       object
# Schadensnummer                   object
# KvaRechnung_ID                   object
# KvaRechnung_Nummer               object
# Forderung_Netto                 float64
# Empfehlung_Netto                float64
# Einigung_Netto                  float64
# DH_ID                             int64
# Land                             object
# PLZ_SO                           object
# PLZ_HW                           object
# PLZ_VN                           object
# address1_postalcode              object
# Schadenart_Name                  object
# Falltyp_Name                     object
# Gewerk_Name                      object
# Kundengruppe                     object
# Differenz_vor_Zeitwert_Netto    float64
# Handwerker_Name                  object
# dtype: object

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868489 entries, 0 to 868488
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Auftrag_ID                    868489 non-null  object
#  1   Schadensnummer                868489 non-null  object
#  2   KvaRechnung_ID                868489 non-null  object
#  3   KvaRechnung_Nummer            868489 non-null  object
#  4   Forderung_Netto               868489 non-null  float64
#  5   Empfehlung_Netto              868489 non-null  float64
#  6   Einigung_Netto                868489 non-null  float64
#  7   DH_ID                         868489 non-null  int64
#  8   Land                          868489 non-null  object
#  9   PLZ_SO                        868489 non-null  object
#  10  PLZ_HW                        868489 non-null  object
#  11  PLZ_VN                        868489 non-null  object
# ...

# %%
# 1. Finde die Spalten, die vom Typ 'object' sind
object_columns = df.select_dtypes('object').columns

# 2. Wende .astype() nur auf diese Spalten an
df[object_columns] = df[object_columns].astype('string')

# %%
df.dtypes
# Out:
# Auftrag_ID                      string[python]
# Schadensnummer                  string[python]
# KvaRechnung_ID                  string[python]
# KvaRechnung_Nummer              string[python]
# Forderung_Netto                        float64
# Empfehlung_Netto                       float64
# Einigung_Netto                         float64
# DH_ID                                    int64
# Land                            string[python]
# PLZ_SO                          string[python]
# PLZ_HW                          string[python]
# PLZ_VN                          string[python]
# address1_postalcode             string[python]
# Schadenart_Name                 string[python]
# Falltyp_Name                    string[python]
# Gewerk_Name                     string[python]
# Kundengruppe                    string[python]
# Differenz_vor_Zeitwert_Netto           float64
# Handwerker_Name                 string[python]
# dtype: object

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868489 entries, 0 to 868488
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Auftrag_ID                    868489 non-null  string
#  1   Schadensnummer                868489 non-null  string
#  2   KvaRechnung_ID                868489 non-null  string
#  3   KvaRechnung_Nummer            868489 non-null  string
#  4   Forderung_Netto               868489 non-null  float64
#  5   Empfehlung_Netto              868489 non-null  float64
#  6   Einigung_Netto                868489 non-null  float64
#  7   DH_ID                         868489 non-null  int64
#  8   Land                          868489 non-null  string
#  9   PLZ_SO                        868489 non-null  string
#  10  PLZ_HW                        868489 non-null  string
#  11  PLZ_VN                        868489 non-null  string
# ...

# %%
# Downcast integer columns
int_cols = df.select_dtypes(include=['int64']).columns
for col in int_cols:
    df[col] = pd.to_numeric(df[col], downcast='integer')

# Downcast float columns
float_cols = df.select_dtypes(include=['float64']).columns
for col in float_cols:
    df[col] = pd.to_numeric(df[col], downcast='float')

print("\n--- Memory Usage After Numeric Downcasting ---")
df.info(memory_usage='deep')# Downcast integer columns
int_cols = df.select_dtypes(include=['int64']).columns
for col in int_cols:
    df[col] = pd.to_numeric(df[col], downcast='integer')

# Downcast float columns
float_cols = df.select_dtypes(include=['float64']).columns
for col in float_cols:
    df[col] = pd.to_numeric(df[col], downcast='float')

print("\n--- Memory Usage After Numeric Downcasting ---")
df.info(memory_usage='deep')
# Out:
# --- Memory Usage After Numeric Downcasting ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868489 entries, 0 to 868488
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Auftrag_ID                    868489 non-null  string
#  1   Schadensnummer                868489 non-null  string
#  2   KvaRechnung_ID                868489 non-null  string
#  3   KvaRechnung_Nummer            868489 non-null  string
#  4   Forderung_Netto               868489 non-null  float64
#  5   Empfehlung_Netto              868489 non-null  float64
#  6   Einigung_Netto                868489 non-null  float64
#  7   DH_ID                         868489 non-null  int8
#  8   Land                          868489 non-null  string
#  9   PLZ_SO                        868489 non-null  string
#  10  PLZ_HW                        868489 non-null  string
# ...

# %%
df.replace('-', None, inplace=True)
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868489 entries, 0 to 868488
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Auftrag_ID                    868489 non-null  string
#  1   Schadensnummer                868489 non-null  string
#  2   KvaRechnung_ID                868489 non-null  string
#  3   KvaRechnung_Nummer            868489 non-null  string
#  4   Forderung_Netto               868489 non-null  float64
#  5   Empfehlung_Netto              868489 non-null  float64
#  6   Einigung_Netto                868489 non-null  float64
#  7   DH_ID                         868489 non-null  int8
#  8   Land                          728837 non-null  string
#  9   PLZ_SO                        728837 non-null  string
#  10  PLZ_HW                        757300 non-null  string
#  11  PLZ_VN                        362717 non-null  string
# ...
